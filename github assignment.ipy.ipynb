# %% [markdown]
# 1. a.
#
# mkdir my-folder
# cd my-folder
#
# 1. b.
#
# touch Code.txt Log.txt Output.txt
#
# 1.c.
#
# git add Code.txt Output.txt
#
# 1.d.
#
# git commit -m "Add Code and Output files"
#
# 1. e.
#
# git init
# git branch -M main
# git remote add origin https://github.com/USERNAME/REPOSITORY-NAME.git
#
# git push -u origin main
#
#
# 2.
# a.
# mkdir git-work
# cd git-work
# git init
# touch feature1.txt feature2.txt
# git add feature1.txt feature2.txt
# git commit -m "Add feature1 and feature2 files"
#
# b.
# git branch develop
# git branch feature1
# git branch feature2
#
# c.
# git checkout develop
# touch develop.txt
#
# d.
# git stash
# git checkout feature1
#
# e.
# touch new.txt
# git add new.txt
# git commit -m "Add new file in feature1 branch"
#
#
# f.
# git checkout develop
# git stash pop
# git add develop.txt
# git commit -m "Add develop file"
#
# g.
# mkdir git-work
# cd git-work
# git init
# touch feature1.txt feature2.txt
# git add feature1.txt feature2.txt
# git commit -m "Add feature1 and feature2 files"
# git branch develop
# git branch feature1
# git branch feature2
# git checkout develop
# touch develop.txt
# git stash
# git checkout feature1
# touch new.txt
# git add new.txt
# git commit -m "Add new file in feature1 branch"
# git checkout develop
# git stash pop
# git add develop.txt
# git commit -m "Add develop file"
#
# 3.
# a.
# mkdir git-task
# cd git-task
# git init
# git branch Develop
# git branch F1
# git branch f2
#
# b.
# touch main.txt
# git add main.txt
# git commit -m "Add main file in master branch"
#
# c.
# git checkout Develop
# touch develop.txt
# git add develop.txt
# git commit -m "Add develop file"
#
# git checkout F1
# touch f1.txt
# git add f1.txt
# git commit -m "Add f1 file"
#
# git checkout f2
# touch f2.txt
# git add f2.txt
# git commit -m "Add f2 file"
#
# d.
# git remote add origin https://github.com/USERNAME/REPOSITORY-NAME.git
#
# git push -u origin master
# git push -u origin Develop
# git push -u origin F1
# git push -u origin f2
#
# e.
# git branch -d f2
#
# f.
# git push origin --delete f2
#
# 4.
# a
# git init
# touch master.txt
# git add master.txt
# git commit -m "Add master file"
#
# b.
# git branch public1
# git branch public2
# git branch private
#
# c.
# git checkout public1
# touch public1.txt
# git add public1.txt
# git commit -m "Add public1 file"
#
# d.
# git checkout master
# git merge public1
#
# e.
# git merge public2
#
# f.
# git checkout private
# nano master.txt   # or use any editor
# git add master.txt
# git commit -m "Update master file in private branch"
#
# g.
# git checkout master
# git merge private
#
# git checkout public1
# git merge master
#
# git checkout public2
# git merge master
#
# h.
# already done in step 7
#
# i.
# git init
# touch master.txt
# git add master.txt
# git commit -m "Add master file"
#
# git branch public1
# git branch public2
# git branch private
#
# git checkout public1
# touch public1.txt
# git add public1.txt
# git commit -m "Add public1 file"
#
# git checkout master
# git merge public1
# git merge public2
#
# git checkout private
# nano master.txt
# git add master.txt
# git commit -m "Update master file in private branch"
#
# git checkout master
# git merge private
#
# git checkout public1
# git merge master
#
# git checkout public2
# git merge master
#
# git checkout private
# git merge master
#
# 5.
# a
# git init
# git flow init
#
# When prompted, accept defaults:
# master branch: master
# develop branch: develop
#
# b.
# Git Flow automatically creates:
# master
# develop
#
# Other branches are created as needed:
# feature/*
# hotfix/*
#
# c.
# git flow feature start feature1
#
# touch feature.txt
# git add feature.txt
# git commit -m "Add feature file"
#
# git flow feature finish feature1
#
# git flow release start v1.0
# git flow release finish v1.0
#
#
# d.
# git flow hotfix start urgent-fix
#
# touch urgent.txt
# git add urgent.txt
# git commit -m "Add urgent fix"
#
# git flow hotfix finish urgent-fix
